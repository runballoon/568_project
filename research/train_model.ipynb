# %%
from yahoo_fin.stock_info import *
from pytickersymbols import PyTickerSymbols
import joblib

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import datetime as dt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
# Out:
# 2023-05-04 19:27:25.054043: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# last window-size data cannot be used to predict because observations don't exist
def split(data, window, future=1):
  X, y=[], []
  for i in range(len(data)-window+1-future+1):
    X.append(data[i:i+window-1, :])
    y.append(data[i+window-1+future-1, :])
  return np.array(X), np.array(y)

# %%
def build_model(X_train):
  # LSTM model
  lstm=Sequential()
  lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))
  lstm.add(LSTM(50, activation='relu'))
  lstm.add(Dense(4))
  lstm.compile(loss='mean_squared_error', optimizer='adam')
  return lstm

# %%
stock_data = PyTickerSymbols()
nasdaq_100_stocks = stock_data.get_nasdaq_100_nyc_yahoo_tickers()

# %%
start_date=dt.date.today()-dt.timedelta(days=1000)
end_date=None
index_as_date=True
interval="1d"

# %%
window=5
future=1
split_ratio=0.8
sc=StandardScaler()
new_sc=StandardScaler()
callback=EarlyStopping(monitor='loss', patience=5, verbose=1, baseline=0.005, restore_best_weights=True)

# %%
acc_pred=[]

# %%
for ticker in nasdaq_100_stocks:
  Xy_data=get_data(ticker, start_date, end_date, index_as_date, interval).dropna().iloc[:, :4]
  Xy_nm=sc.fit_transform(Xy_data.values)
  Xy_nm=pd.DataFrame(data=Xy_nm, index=Xy_data.index, columns=Xy_data.columns)

  X_split, y_split=split(Xy_nm.values, window, future)
  split_idx=int(len(X_split)*split_ratio)
  date_index=Xy_nm.index[:(-1)*window+1+(-1)*future+1]

  X_train, X_test=X_split[:split_idx], X_split[split_idx:]
  y_train, y_test=y_split[:split_idx], y_split[split_idx:]
  X_train_date, X_test_date=date_index[:split_idx], date_index[split_idx:]

  model=build_model(X_train)
  history=model.fit(X_train, y_train, batch_size=4, epochs=50, verbose=2, shuffle=False)

  y_pred=model.predict(X_test)
  accu=r2_score(y_test, y_pred)

  future_pred_X=np.array([Xy_nm.values[(-1)*window+1+(-1)*future+1:, :]])
  future_pred_y=model.predict(future_pred_X)

  new_sc.scale_, new_sc.mean_, new_sc.var_=sc.scale_[-1], sc.mean_[-1], sc.var_[-1]
  future_pred_close=new_sc.inverse_transform(future_pred_y)
  acc_pred.append((accu, future_pred_close))
  model_joblib_dir=f"./{ticker}.joblib"
  sc_joblib_dir=f"./sc_{ticker}.joblib"
  joblib.dump(sc, sc_joblib_dir, compress=True)
  joblib.dump(model, model_joblib_dir, compress=True)
  break
# Out:
# Epoch 1/50
# 137/137 - 3s - loss: 0.3138 - 3s/epoch - 25ms/step
# Epoch 2/50
# 137/137 - 1s - loss: 0.0707 - 626ms/epoch - 5ms/step
# Epoch 3/50
# 137/137 - 1s - loss: 0.0499 - 520ms/epoch - 4ms/step
# Epoch 4/50
# 137/137 - 0s - loss: 0.0397 - 488ms/epoch - 4ms/step
# Epoch 5/50
# 137/137 - 0s - loss: 0.0314 - 480ms/epoch - 4ms/step
# Epoch 6/50
# 137/137 - 1s - loss: 0.0309 - 549ms/epoch - 4ms/step
# Epoch 7/50
# 137/137 - 0s - loss: 0.0263 - 476ms/epoch - 3ms/step
# Epoch 8/50
# 137/137 - 0s - loss: 0.0300 - 474ms/epoch - 3ms/step
# Epoch 9/50
# 137/137 - 1s - loss: 0.0249 - 512ms/epoch - 4ms/step
# Epoch 10/50
# 137/137 - 1s - loss: 0.0276 - 511ms/epoch - 4ms/step
# Epoch 11/50
# 137/137 - 1s - loss: 0.0245 - 561ms/epoch - 4ms/step
# Epoch 12/50
# 137/137 - 1s - loss: 0.0269 - 620ms/epoch - 5ms/step
# Epoch 13/50
# 137/137 - 1s - loss: 0.0257 - 625ms/epoch - 5ms/step
# Epoch 14/50
# 137/137 - 1s - loss: 0.0275 - 543ms/epoch - 4ms/step
# Epoch 15/50
# 137/137 - 0s - loss: 0.0270 - 473ms/epoch - 3ms/step
# Epoch 16/50
# 137/137 - 0s - loss: 0.0275 - 457ms/epoch - 3ms/step
# Epoch 17/50
# 137/137 - 0s - loss: 0.0270 - 482ms/epoch - 4ms/step
# Epoch 18/50
# 137/137 - 1s - loss: 0.0268 - 529ms/epoch - 4ms/step
# Epoch 19/50
# 137/137 - 1s - loss: 0.0266 - 703ms/epoch - 5ms/step
# Epoch 20/50
# 137/137 - 1s - loss: 0.0265 - 648ms/epoch - 5ms/step
# Epoch 21/50
# 137/137 - 1s - loss: 0.0264 - 632ms/epoch - 5ms/step
# Epoch 22/50
# 137/137 - 1s - loss: 0.0263 - 635ms/epoch - 5ms/step
# Epoch 23/50
# 137/137 - 1s - loss: 0.0262 - 506ms/epoch - 4ms/step
# Epoch 24/50
# 137/137 - 0s - loss: 0.0262 - 480ms/epoch - 4ms/step
# Epoch 25/50
# 137/137 - 0s - loss: 0.0251 - 488ms/epoch - 4ms/step
# Epoch 26/50
# 137/137 - 0s - loss: 0.0267 - 462ms/epoch - 3ms/step
# Epoch 27/50
# 137/137 - 0s - loss: 0.0255 - 491ms/epoch - 4ms/step
# Epoch 28/50
# 137/137 - 0s - loss: 0.0263 - 452ms/epoch - 3ms/step
# Epoch 29/50
# 137/137 - 0s - loss: 0.0260 - 478ms/epoch - 3ms/step
# Epoch 30/50
# 137/137 - 0s - loss: 0.0263 - 469ms/epoch - 3ms/step
# Epoch 31/50
# 137/137 - 0s - loss: 0.0257 - 473ms/epoch - 3ms/step
# Epoch 32/50
# 137/137 - 0s - loss: 0.0259 - 477ms/epoch - 3ms/step
# Epoch 33/50
# 137/137 - 0s - loss: 0.0252 - 468ms/epoch - 3ms/step
# Epoch 34/50
# 137/137 - 0s - loss: 0.0258 - 482ms/epoch - 4ms/step
# Epoch 35/50
# 137/137 - 0s - loss: 0.0251 - 471ms/epoch - 3ms/step
# Epoch 36/50
# 137/137 - 1s - loss: 0.0257 - 501ms/epoch - 4ms/step
# Epoch 37/50
# 137/137 - 0s - loss: 0.0251 - 484ms/epoch - 4ms/step
# Epoch 38/50
# 137/137 - 0s - loss: 0.0254 - 498ms/epoch - 4ms/step
# Epoch 39/50
# 137/137 - 0s - loss: 0.0246 - 465ms/epoch - 3ms/step
# Epoch 40/50
# 137/137 - 0s - loss: 0.0252 - 471ms/epoch - 3ms/step
# Epoch 41/50
# 137/137 - 0s - loss: 0.0241 - 478ms/epoch - 3ms/step
# Epoch 42/50
# 137/137 - 0s - loss: 0.0252 - 471ms/epoch - 3ms/step
# Epoch 43/50
# 137/137 - 0s - loss: 0.0238 - 482ms/epoch - 4ms/step
# Epoch 44/50
# 137/137 - 1s - loss: 0.0245 - 514ms/epoch - 4ms/step
# Epoch 45/50
# 137/137 - 1s - loss: 0.0239 - 540ms/epoch - 4ms/step
# Epoch 46/50
# 137/137 - 0s - loss: 0.0244 - 469ms/epoch - 3ms/step
# Epoch 47/50
# 137/137 - 0s - loss: 0.0238 - 473ms/epoch - 3ms/step
# Epoch 48/50
# 137/137 - 0s - loss: 0.0240 - 488ms/epoch - 4ms/step
# Epoch 49/50
# 137/137 - 0s - loss: 0.0240 - 461ms/epoch - 3ms/step
# Epoch 50/50
# 137/137 - 0s - loss: 0.0238 - 484ms/epoch - 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 24ms/step
# Epoch 1/50
# 137/137 - 2s - loss: 0.3767 - 2s/epoch - 17ms/step
# Epoch 2/50
# 137/137 - 0s - loss: 0.1180 - 479ms/epoch - 3ms/step
# Epoch 3/50
# 137/137 - 0s - loss: 0.0701 - 492ms/epoch - 4ms/step
# Epoch 4/50
# 137/137 - 1s - loss: 0.0546 - 538ms/epoch - 4ms/step
# Epoch 5/50
# 137/137 - 0s - loss: 0.0465 - 468ms/epoch - 3ms/step
# Epoch 6/50
# 137/137 - 0s - loss: 0.0445 - 462ms/epoch - 3ms/step
# Epoch 7/50
# 137/137 - 0s - loss: 0.0431 - 462ms/epoch - 3ms/step
# Epoch 8/50
# 137/137 - 0s - loss: 0.0424 - 462ms/epoch - 3ms/step
# Epoch 9/50
# 137/137 - 0s - loss: 0.0421 - 460ms/epoch - 3ms/step
# Epoch 10/50
# 137/137 - 0s - loss: 0.0417 - 469ms/epoch - 3ms/step
# Epoch 11/50
# 137/137 - 0s - loss: 0.0415 - 468ms/epoch - 3ms/step
# Epoch 12/50
# 137/137 - 0s - loss: 0.0413 - 469ms/epoch - 3ms/step
# Epoch 13/50
# 137/137 - 0s - loss: 0.0412 - 459ms/epoch - 3ms/step
# Epoch 14/50
# 137/137 - 0s - loss: 0.0411 - 469ms/epoch - 3ms/step
# Epoch 15/50
# 137/137 - 0s - loss: 0.0412 - 468ms/epoch - 3ms/step
# Epoch 16/50
# 137/137 - 0s - loss: 0.0415 - 450ms/epoch - 3ms/step
# Epoch 17/50
# 137/137 - 0s - loss: 0.0420 - 479ms/epoch - 3ms/step
# Epoch 18/50
# 137/137 - 0s - loss: 0.0415 - 457ms/epoch - 3ms/step
# Epoch 19/50
# 137/137 - 0s - loss: 0.0425 - 483ms/epoch - 4ms/step
# Epoch 20/50
# 137/137 - 0s - loss: 0.0429 - 455ms/epoch - 3ms/step
# Epoch 21/50
# 137/137 - 0s - loss: 0.0437 - 464ms/epoch - 3ms/step
# Epoch 22/50
# 137/137 - 0s - loss: 0.0438 - 481ms/epoch - 4ms/step
# Epoch 23/50
# 137/137 - 0s - loss: 0.0444 - 461ms/epoch - 3ms/step
# Epoch 24/50
# 137/137 - 0s - loss: 0.0439 - 471ms/epoch - 3ms/step
# Epoch 25/50
# 137/137 - 0s - loss: 0.0438 - 462ms/epoch - 3ms/step
# Epoch 26/50
# 137/137 - 0s - loss: 0.0437 - 465ms/epoch - 3ms/step
# Epoch 27/50
# 137/137 - 0s - loss: 0.0433 - 465ms/epoch - 3ms/step
# Epoch 28/50
# 137/137 - 0s - loss: 0.0431 - 469ms/epoch - 3ms/step
# Epoch 29/50
# 137/137 - 0s - loss: 0.0428 - 470ms/epoch - 3ms/step
# Epoch 30/50
# 137/137 - 0s - loss: 0.0429 - 470ms/epoch - 3ms/step
# Epoch 31/50
# 137/137 - 0s - loss: 0.0433 - 477ms/epoch - 3ms/step
# Epoch 32/50
# 137/137 - 1s - loss: 0.0423 - 549ms/epoch - 4ms/step
# Epoch 33/50
# 137/137 - 1s - loss: 0.0424 - 586ms/epoch - 4ms/step
# Epoch 34/50
# 137/137 - 1s - loss: 0.0423 - 590ms/epoch - 4ms/step
# Epoch 35/50
# 137/137 - 1s - loss: 0.0421 - 563ms/epoch - 4ms/step
# Epoch 36/50
# 137/137 - 1s - loss: 0.0420 - 512ms/epoch - 4ms/step
# Epoch 37/50
# 137/137 - 1s - loss: 0.0420 - 558ms/epoch - 4ms/step
# Epoch 38/50
# 137/137 - 1s - loss: 0.0414 - 570ms/epoch - 4ms/step
# Epoch 39/50
# 137/137 - 1s - loss: 0.0414 - 504ms/epoch - 4ms/step
# Epoch 40/50
# 137/137 - 0s - loss: 0.0412 - 471ms/epoch - 3ms/step
# Epoch 41/50
# 137/137 - 0s - loss: 0.0409 - 478ms/epoch - 3ms/step
# Epoch 42/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/01/j3xtswpx7773d5fkjjdnvjmw0000gn/T/ipykernel_30529/758127141.py in <module>
#      13
#      14   model=build_model(X_train)
# ---> 15   history=model.fit(X_train, y_train, batch_size=4, epochs=50, verbose=2, shuffle=False)
#      16
#      17   y_pred=model.predict(X_test)
#
# /opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
